# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

Image.MAX_IMAGE_PIXELS = 933120000
filename = "S1A_IW_GRDH_1SDV_20240323T094000_20240323T094025_053107_066EC8_11F5.SAFE"

# %%
image_path = "./output_tif/subset_5_of_final_S1A_IW_GRDH_1SDV_20240131T101241_20240131T101306_052349_065480_3565_new_mask.tif"
img = Image.open(image_path)

# %%
# Convert the image to numpy array
img_array = np.array(img)

# Plot the image
plt.imshow(img_array, cmap='gray')  # You can change the colormap as per your need
plt.axis('off')  # Turn off axis
plt.show()
